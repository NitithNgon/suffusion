# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
img1 = plt.imread('./asset/Suffusion.png')
plt.imshow(img1)
plt.show()

img = cv.imread('./asset/Suffusion.png',cv.IMREAD_GRAYSCALE)
# img2 = cv.imread('./asset/Suffusion2.png',cv.IMREAD_GRAYSCALE)
# print(img2)
plt.imshow(img, cmap="gray")
plt.show()
img=(img-150)//(20)
plt.imshow(img, cmap="gray")
plt.show()
# for i in range(img.shape[0]):
#     for j in range(img.shape[1]):
#         if img[i,j]==1:
#             img[i,j]=10
plt.hist(img[:,:].ravel(),151,[1,12],color='red')
plt.figure(figsize=(20,16),dpi=100)
plt.imshow(img, cmap="gray")
plt.grid(False)
unique, counts = np.unique(img, return_counts=True)
a=dict(zip(unique, counts))
print(a)
b=a[0]
print(img.shape[0]*img.shape[1])
#Calculate percentage of water hyacinth
r=img.shape[0]*img.shape[1]
print("{0}{1}".format(b*100//r,"%"))
# Out:
# {0: 41148, 1: 23087, 2: 736, 7: 1, 8: 50, 9: 191, 10: 4088, 11: 10502, 12: 39060}
# 118863
# 34%

# %%
def normalize(img):
    lmin = float(img.min())
    lmax = float(img.max())
    return ((img-lmin)//(lmax-lmin))

# %%
0.2989*192+0.5870*100+0.1140*100
# Out:
# 127.4888

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

img1 = plt.imread('./asset/Suffusion.png')
print(float(img1.min()),float(img1.max()))
plt.imshow(img1, cmap='gray')
plt.show()
img=normalize(img1)
# for i in range(img.shape[0]):
#     for j in range(img.shape[1]):
#         if img[i,j]==1:
#             img[i,j]=0
plt.imshow(img, cmap='gray')
plt.show()
plt.hist(img[:,:].ravel(),255,[0,1],color='red')
plt.figure(figsize=(20,16),dpi=100)
unique, counts = np.unique(img, return_counts=True)
a=dict(zip(unique, counts))
print(a)
print("{0}{1}".format((a[1.0]*100)/(a[0.0]+a[1.0]), "%"))
# Out:
# 0.1921568661928177 1.0
# {0.0: 354637, 1.0: 120815}
# 25.410556691316895%

# %%
https://stackoverflow.com/questions/66757199/color-percentage-in-image-for-python-using-opencv

# %%
https://www.quora.com/Is-there-a-way-to-find-a-specific-color-percentage-of-an-image-using-OpenCV-with-Python

# %%
import cv2 as cv
import numpy as np
from 9 import pyplot as plt
# %matplotlib inline
img1 = plt.imread('./asset/Suffusion.png')
plt.imshow(img1)
plt.show()

img = cv.imread('./asset/Suffusion.png',cv.IMREAD_GRAYSCALE)
# img2 = cv.imread('./asset/Suffusion2.png',cv.IMREAD_GRAYSCALE)
# print(img2)
plt.imshow(img, cmap="gray")
plt.show()
img=(img-150)//(20)
plt.imshow(img, cmap="gray")
plt.show()
# for i in range(img.shape[0]):
#     for j in range(img.shape[1]):
#         if img[i,j]==1:
#             img[i,j]=10
plt.hist(img[:,:].ravel(),151,[1,12],color='red')
plt.figure(figsize=(20,16),dpi=100)
plt.imshow(img, cmap="gray")
plt.grid(False)
unique, counts = np.unique(img, return_counts=True)
a=dict(zip(unique, counts))
print(a)
b=a[0]
print(img.shape[0]*img.shape[1])
#Calculate percentage of water hyacinth
r=img.shape[0]*img.shape[1]
print("{0}{1}".format(b*100//r,"%"))
